# %%
import numpy as np                                                 # Implemennts milti-dimensional array and matrices
import pandas as pd                                                # For data manipulation and analysis
import pandas_profiling 
import matplotlib.pyplot as plt                                    # Plotting library for Python programming language and it's numerical mathematics extension NumPy
import seaborn as sns  
##conda install -c conda-forge geopy
# Provides a high level interface for drawing attractive and informative statistical graphics
from geopy.geocoders import Nominatim
# %matplotlib inline
sns.set()

##from subprocess import check_output
##zomato = pd.read_csv("https://www.kaggle.com/himanshupoddar/zomato-bangalore-restaurants#zomato.csv")

# %%
#import necessary modules
zomato = pd.read_csv("zomato.csv")

# %%
zomato.shape
# Out:
# (51717, 17)

# %%
zomato.head()
# Out:
#                                                  url  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              address                   name  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   online_order book_table   rate  votes                             phone  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato.isnull().sum()
# Out:
# url                                0
# address                            0
# name                               0
# online_order                       0
# book_table                         0
# rate                            7775
# votes                              0
# phone                           1208
# location                          21
# rest_type                        227
# dish_liked                     28078
# cuisines                          45
# approx_cost(for two people)      346
# reviews_list                       0
# menu_item                          0
# listed_in(type)                    0
# listed_in(city)                    0
# dtype: int64

# %%
zomato.describe(include = 'all')
# Out:
#                                                       url        address  \
# count                                               51717          51717
# unique                                              51717          11495
# top     https://www.zomato.com/bangalore/om-ganesha-ju...  Delivery Only
# freq                                                    1            128
# mean                                                  NaN            NaN
# std                                                   NaN            NaN
# min                                                   NaN            NaN
# 25%                                                   NaN            NaN
# 50%                                                   NaN            NaN
# 75%                                                   NaN            NaN
# max                                                   NaN            NaN
#
#                    name online_order book_table   rate         votes  \
# ...

# %%
print("Workable fields include Online_order, book_table, rate, votes, approx_cost(for two people), listed_on(type)")
# Out:
# Workable fields include Online_order, book_table, rate, votes, approx_cost(for two people), listed_on(type)

# %%
profile = pandas_profiling.ProfileReport(zomato)
profile.to_file(outputfile="zomato_before_preprocessing.html")

# %%
zomato.columns = map(str.upper, zomato.columns)                                  # map() function returns a list of results after applying the given function
                                                                         # to each item of a given iterable.
zomato.dtypes                                                                # Confirm that all variable names are now lower case

##For upper case 
##mh.columns = map(str.upper, mh.columns)
# Out:
# URL                            object
# ADDRESS                        object
# NAME                           object
# ONLINE_ORDER                   object
# BOOK_TABLE                     object
# RATE                           object
# VOTES                           int64
# PHONE                          object
# LOCATION                       object
# REST_TYPE                      object
# DISH_LIKED                     object
# CUISINES                       object
# APPROX_COST(FOR TWO PEOPLE)    object
# REVIEWS_LIST                   object
# MENU_ITEM                      object
# LISTED_IN(TYPE)                object
# LISTED_IN(CITY)                object
# dtype: object

# %%
profile = pandas_profiling.ProfileReport(zomato)
profile.to_file(outputfile="zomato_before_preprocessing.html")

# %%
sns.factorplot('BOOK_TABLE', data=zomato, kind='count')
plt.title('Factorplot with # of Restaurants that allowed booking table for Zomato, Bengaluru restaurants')
# Out:
# Text(0.5,1,'Factorplot with # of Restaurants that allowed booking table for Zomato, Bengaluru restaurants')

# %%
print("Only 12.5% of restaurants on Zomato, Bengaluru allow booking a table ahead")
# Out:
# Only 12.5% of restaurants on Zomato, Bengaluru allow booking a table ahead

# %%
sns.factorplot('ONLINE_ORDER', data=zomato, kind='count')
plt.title('Factorplot with # of Restaurants that allowed Online ordering for Zomato, Bengaluru restaurants')
# Out:
# Text(0.5,1,'Factorplot with # of Restaurants that allowed Online ordering for Zomato, Bengaluru restaurants')

# %%
print("A Huge majority of ~58.9% of restaurants on Zomato, Bengaluru allow online ordering")
# Out:
# A Huge majority of ~58.9% of restaurants on Zomato, Bengaluru allow online ordering

# %%
sns.factorplot('RATE', data=zomato, kind='count')
plt.title('Factorplot with Rating distribution for Zomato, Bengaluru restaurants')
# Out:
# Text(0.5,1,'Factorplot with Rating distribution for Zomato, Bengaluru restaurants')

# %%
zomato['RATE'].value_counts().head(75).plot.bar()

# %%
zomato['RATE'].value_counts().head(75).sort_index().plot.bar()

# %%
print("Ratings data shows a Normal distribution with ~22.6% restaurants rated between 3.7-3.9/5 and ~4.3% New restaurants without a valid rating and 15% with missing ratings")
# Out:
# Ratings data shows a Normal distribution with ~22.6% restaurants rated between 3.7-3.9/5 and ~4.3% New restaurants without a valid rating and 15% with missing ratings

# %%
print(zomato['RATE'].unique())
# Out:
# ['4.1/5' '3.8/5' '3.7/5' '3.6/5' '4.6/5' '4.0/5' '4.2/5' '3.9/5' '3.1/5'
#  '3.0/5' '3.2/5' '3.3/5' '2.8/5' '4.4/5' '4.3/5' 'NEW' '2.9/5' '3.5/5' nan
#  '2.6/5' '3.8 /5' '3.4/5' '4.5/5' '2.5/5' '2.7/5' '4.7/5' '2.4/5' '2.2/5'
#  '2.3/5' '3.4 /5' '-' '3.6 /5' '4.8/5' '3.9 /5' '4.2 /5' '4.0 /5' '4.1 /5'
#  '3.7 /5' '3.1 /5' '2.9 /5' '3.3 /5' '2.8 /5' '3.5 /5' '2.7 /5' '2.5 /5'
#  '3.2 /5' '2.6 /5' '4.5 /5' '4.3 /5' '4.4 /5' '4.9/5' '2.1/5' '2.0/5'
#  '1.8/5' '4.6 /5' '4.9 /5' '3.0 /5' '4.8 /5' '2.3 /5' '4.7 /5' '2.4 /5'
#  '2.1 /5' '2.2 /5' '2.0 /5' '1.8 /5']

# %%
zomato_fix = zomato.copy(deep=True)

# %%
#There are only 15% of RATING data missing so let's replace NaN with mode()
#Replace "NaN" string from defaultString
zomato_fix['RATE'] = zomato['RATE'].fillna(zomato['RATE'].mode()[0])
print(zomato_fix['RATE'].unique())
# Out:
# ['4.1/5' '3.8/5' '3.7/5' '3.6/5' '4.6/5' '4.0/5' '4.2/5' '3.9/5' '3.1/5'
#  '3.0/5' '3.2/5' '3.3/5' '2.8/5' '4.4/5' '4.3/5' 'NEW' '2.9/5' '3.5/5'
#  '2.6/5' '3.8 /5' '3.4/5' '4.5/5' '2.5/5' '2.7/5' '4.7/5' '2.4/5' '2.2/5'
#  '2.3/5' '3.4 /5' '-' '3.6 /5' '4.8/5' '3.9 /5' '4.2 /5' '4.0 /5' '4.1 /5'
#  '3.7 /5' '3.1 /5' '2.9 /5' '3.3 /5' '2.8 /5' '3.5 /5' '2.7 /5' '2.5 /5'
#  '3.2 /5' '2.6 /5' '4.5 /5' '4.3 /5' '4.4 /5' '4.9/5' '2.1/5' '2.0/5'
#  '1.8/5' '4.6 /5' '4.9 /5' '3.0 /5' '4.8 /5' '2.3 /5' '4.7 /5' '2.4 /5'
#  '2.1 /5' '2.2 /5' '2.0 /5' '1.8 /5']

# %%
profile = pandas_profiling.ProfileReport(zomato_fix)
profile.to_file(outputfile="zomato_after_preprocessing.html")

# %%
import pylab
pylab.ylim(0,2200)
zomato_fix['RATE'].value_counts().head(75).sort_index().plot.bar()

# %%
print("Ratings data shows a Normal distribution with ~22.6% restaurants rated between 3.7-3.9/5 and ~19.3% New restaurants without a valid rating including the Resturants with missing ratings")
# Out:
# Ratings data shows a Normal distribution with ~22.6% restaurants rated between 3.7-3.9/5 and ~19.3% New restaurants without a valid rating including the Resturants with missing ratings

# %%
zomato['NAME'].value_counts().head(50).plot.bar()

# %%
print("Top 5 restaurants by vote include 'Cafe Coffee Day', 'Onesta', 'Just Bake','Empire Resturant' and 'Five Star Chicken'")
# Out:
# Top 5 restaurants by vote include 'Cafe Coffee Day', 'Onesta', 'Just Bake','Empire Resturant' and 'Five Star Chicken'

# %%
zomato['NAME'].value_counts().head(10).sort_index().plot.bar()

# %%
zomato['NAME'].value_counts().head(10).plot.bar()

# %%
##zomato_numeric = data.frame(lapply(zomato.APPROX_COST(FOR_TWO_PEOPLE), as.numeric))
##def f(x):
 ##   return pd.factorize(x)[0]
##zomato_new.apply(f)

##zomato_new['cost_numeric'] = pd.zomato_new.APPROX_COST(FOR_TWO_PEOPLE).codes
##for col_name in df.columns:
##if(df[col_name].dtype == 'object'):
 ##   df[col_name]= df[col_name].astype('category')
 ##   df[col_name]= df[col_name].cat.codes

# %%
zomato.head()
# Out:
#                                                  URL  \
# 0  https://www.zomato.com/bangalore/jalsa-banasha...
# 1  https://www.zomato.com/bangalore/spice-elephan...
# 2  https://www.zomato.com/SanchurroBangalore?cont...
# 3  https://www.zomato.com/bangalore/addhuri-udupi...
# 4  https://www.zomato.com/bangalore/grand-village...
#
#                                              ADDRESS                   NAME  \
# 0  942, 21st Main Road, 2nd Stage, Banashankari, ...                  Jalsa
# 1  2nd Floor, 80 Feet Road, Near Big Bazaar, 6th ...         Spice Elephant
# 2  1112, Next to KIMS Medical College, 17th Cross...        San Churro Cafe
# 3  1st Floor, Annakuteera, 3rd Stage, Banashankar...  Addhuri Udupi Bhojana
# 4  10, 3rd Floor, Lakshmi Associates, Gandhi Baza...          Grand Village
#
#   ONLINE_ORDER BOOK_TABLE   RATE  VOTES                             PHONE  \
# 0          Yes        Yes  4.1/5    775    080 42297555\r\n+91 9743772233
# ...

# %%
zomato_new = zomato.copy(deep=True)   # creating new dataframe to make any datatype changes over it and keep the original dataframe as it is..
from sklearn.preprocessing import LabelEncoder                                    # Label encoder is used to transform non-numerical labels to numerical labels.
number = LabelEncoder()                                                           # Here as our data set consists only of categorical values except age
for i in zomato_new.columns:                                                          # in order to find the correlation between variables, we do Label encoding 
    zomato_new[i] = number.fit_transform(zomato_new[i].astype('str'))
zomato_new.head()
# Out:
#      URL  ADDRESS  NAME  ONLINE_ORDER  BOOK_TABLE  RATE  VOTES  PHONE  \
# 0  22195     8016  3690             1           1    46   2094  13293
# 1  41273     3844  7022             1           0    46   2109  13078
# 2     92      784  6499             1           0    40   2253   7145
# 3   1160     2515   199             0           0    38   2208   6770
# 4  18293      340  2940             0           0    40    532   2006
#
#    LOCATION  REST_TYPE  DISH_LIKED  CUISINES  APPROX_COST(FOR TWO PEOPLE)  \
# 0         1         27        3651      2159                           66
# 1         1         27        2964       952                           66
# 2         1         22        1416       766                           66
# 3         1         78        2766      2555                           42
# 4         4         27        3453      2188                           60
#
#    REVIEWS_LIST  MENU_ITEM  LISTED_IN(TYPE)  LISTED_IN(CITY)
# ...

# %%
zomato_new.describe(include = 'all')
# Out:
#                 URL       ADDRESS          NAME  ONLINE_ORDER    BOOK_TABLE  \
# count  51717.000000  51717.000000  51717.000000  51717.000000  51717.000000
# mean   25858.000000   5555.741632   4330.682754      0.588665      0.124698
# std    14929.556273   3286.922532   2554.840627      0.492080      0.330379
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%    12929.000000   2680.000000   2055.000000      0.000000      0.000000
# 50%    25858.000000   5485.000000   4293.000000      1.000000      0.000000
# 75%    38787.000000   8324.000000   6557.000000      1.000000      0.000000
# max    51716.000000  11494.000000   8791.000000      1.000000      1.000000
#
#                RATE         VOTES         PHONE      LOCATION     REST_TYPE  \
# count  51717.000000  51717.000000  51717.000000  51717.000000  51717.000000
# mean      42.538836    975.606319   7779.317787     36.071969     51.429453
# ...

# %%
#There are 0.7% of Approx cost for  people data missing so let's replace NaN with mode()
#Replace "NaN" string from defaultString
print(zomato['APPROX_COST(FOR TWO PEOPLE)'].unique())
zomato_fix['APPROX_COST(FOR TWO PEOPLE)'] = zomato['APPROX_COST(FOR TWO PEOPLE)'].fillna(zomato['APPROX_COST(FOR TWO PEOPLE)'].mode()[0])
##print(zomato_fix['RATE'].unique())
# Out:
# ['800' '300' '600' '700' '550' '500' '450' '650' '400' '900' '200' '750'
#  '150' '850' '100' '1,200' '350' '250' '950' '1,000' '1,500' '1,300' '199'
#  '80' '1,100' '160' '1,600' '230' '130' '50' '190' '1,700' nan '1,400'
#  '180' '1,350' '2,200' '2,000' '1,800' '1,900' '330' '2,500' '2,100'
#  '3,000' '2,800' '3,400' '40' '1,250' '3,500' '4,000' '2,400' '2,600'
#  '120' '1,450' '469' '70' '3,200' '60' '560' '240' '360' '6,000' '1,050'
#  '2,300' '4,100' '5,000' '3,700' '1,650' '2,700' '4,500' '140']

# %%
#There are 0.7% of Approx cost for  people data missing so let's replace NaN with mode()
#Replace "NaN" string from defaultString
zomato_fix['APPROX_COST(FOR TWO PEOPLE)'] = zomato['APPROX_COST(FOR TWO PEOPLE)'].fillna(zomato['APPROX_COST(FOR TWO PEOPLE)'].mode()[0])
print(zomato_fix['APPROX_COST(FOR TWO PEOPLE)'].unique())
# Out:
# ['800' '300' '600' '700' '550' '500' '450' '650' '400' '900' '200' '750'
#  '150' '850' '100' '1,200' '350' '250' '950' '1,000' '1,500' '1,300' '199'
#  '80' '1,100' '160' '1,600' '230' '130' '50' '190' '1,700' '1,400' '180'
#  '1,350' '2,200' '2,000' '1,800' '1,900' '330' '2,500' '2,100' '3,000'
#  '2,800' '3,400' '40' '1,250' '3,500' '4,000' '2,400' '2,600' '120'
#  '1,450' '469' '70' '3,200' '60' '560' '240' '360' '6,000' '1,050' '2,300'
#  '4,100' '5,000' '3,700' '1,650' '2,700' '4,500' '140']

# %%
profile = pandas_profiling.ProfileReport(zomato_fix)
profile.to_file(outputfile="zomato_after_preprocessing.html")

# %%
zomato_fix['APPROX_COST(FOR TWO PEOPLE)'].value_counts().plot.bar()

# %%
zomato_fix['APPROX_COST(FOR TWO PEOPLE)'].value_counts().head(20).plot.bar()

# %%
plt.figure(figsize=(7,7))
cuisines=zomato_fix['CUISINES'].value_counts()[:15]
sns.barplot(cuisines,cuisines.index)
plt.xlabel('Count')
plt.title("Top 15 Cusines of Bangalore")
# Out:
# Text(0.5,1,'Top 15 Cusines of Bangalore')

# %%
corr=zomato_new.corr()['RATE']
corr[np.argsort(corr,axis=0)[::-1]]
# Out:
# RATE                           1.000000
# REVIEWS_LIST                   0.430843
# BOOK_TABLE                     0.120170
# MENU_ITEM                      0.063947
# DISH_LIKED                     0.043749
# LOCATION                       0.034516
# ADDRESS                        0.020579
# LISTED_IN(TYPE)                0.016577
# REST_TYPE                      0.007890
# NAME                           0.004367
# URL                           -0.000792
# LISTED_IN(CITY)               -0.028311
# CUISINES                      -0.032267
# PHONE                         -0.036015
# APPROX_COST(FOR TWO PEOPLE)   -0.124718
# ONLINE_ORDER                  -0.167062
# VOTES                         -0.493170
# Name: RATE, dtype: float64

# %%
features_correlation = zomato_new.corr()
plt.figure(figsize=(8,8))
sns.heatmap(features_correlation,vmax=1,square=True,annot=False,cmap='Blues')
plt.show()

# %%
corr = zomato_new.corr()
plt.figure(figsize=(10,10))
sns.heatmap(corr,vmax=.8,linewidth=.01, square = True, cmap='YlGnBu',linecolor ='black')
plt.title('Correlation between features')
# Out:
# Text(0.5,1,'Correlation between features')

# %%
zomato_fix['LOCATION'].value_counts().head(20).plot.bar()

# %%
import pylab
pylab.ylim(0,6000)
zomato_fix['LOCATION'].value_counts().head(50).plot.bar()

# %%
sns.countplot('LOCATION',data=zomato_fix, hue='ONLINE_ORDER')

# %%
dummy = zomato_new.div(zomato_fix.sum(1).astype(float), axis=0).plot(kind="bar", stacked=True)
dummy = plt.xlabel('LOCATION')

# %%
sns.set(color_codes=True)                                                # Plot a histogram of the locations (remove any NaN values)
sns.set_palette(sns.color_palette("muted"))

sns.distplot(zomato_new["LOCATION"].dropna());

# %%
f = (zomato_fix
         .loc[zomato_fix['LOCATION'].isin(['BTM', 'HSR','JP Nagar','Indiranagar','Jayanagar','Marathahalli','Bannerghatta Road'])])
fig,ax =plt.subplots(figsize=(8,6))
sns.countplot(data = f,x = 'LOCATION', hue='ONLINE_ORDER')
plt.title('Location vs Online ordering')

# %%
zomato_fix['REST_TYPE'].value_counts().head(20).plot.bar()

# %%
import pylab
pylab.ylim(0,20000)
zomato_fix['REST_TYPE'].value_counts().head(50).plot.bar()

# %%
plt.figure(figsize=(7,7))
rest=zomato_fix['REST_TYPE'].value_counts()[:20]
sns.barplot(rest,rest.index)
plt.title("Restaurant types")
plt.xlabel("count")

# %%
f_num = (zomato_new
         .loc[zomato_new['LOCATION'].isin(['BTM', 'HSR','JP Nagar','Indiranagar','Jayanagar','Marathahalli','Bannerghatta Road'])])
fig,ax =plt.subplots(figsize=(8,6))
sns.countplot(data = f_num,x = 'LOCATION', hue='ONLINE_ORDER')
plt.title('Location vs Online ordering')

sns.set(style='whitegrid', palette='muted')
sns.swarmplot(x="APPROX_COST(FOR TWO PEOPLE)", y="LOCATION", hue="ONLINE_ORDER", palette="gnuplot", data=f_num)

# %%
zomato_new.plot.hexbin(x='LOCATION', y='RATE', gridsize=12)

# %%
zomato_new.plot.hexbin(x='APPROX_COST(FOR TWO PEOPLE)', y='RATE', gridsize=12)

# %%
zomato_new.plot.hexbin(x='ONLINE_ORDER', y='RATE', gridsize=12)
